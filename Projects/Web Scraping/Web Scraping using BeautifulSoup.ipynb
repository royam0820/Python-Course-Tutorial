# %% [markdown]
# # Web Scraping
# Web Scraping is the process of extracting information from a web page by taking advantage of patterns in the web page's underlying code.
#
# For web scraping there are a few different libraries to consider, including:
#
# - [Beautiful Soup](https://pypi.org/project/beautifulsoup4/)
# - [Requests](http://docs.python-requests.org/en/master/)
# - [Scrapy](https://scrapy.org/)
# - [Selenium](https://selenium-python.readthedocs.io/)
#
# In this tutorial, we will go through a simple example of how to scrape a website to gather data on [the top 100 companies in 2018 from Fast Track](http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/). Automating this process with a web scraper avoids manual data gathering, saves time and also allows you to have all the data on the companies in one structured file.
#
# For this example we will be using Beautiful Soup.

# %% [markdown]
# ## HTML Tags
# Do get familiar with HTML tags!
#
# https://www.w3schools.com/
#
# ### HTML Tags Meaning
# https://html-css-js.com/html/tags/

# %% [markdown]
# # HTML CheatSheet
# https://htmlcheatsheet.com/  an online cheatsheet

# %% [markdown]
# ## Inspect the webpage
# Before coding let's first inspect the webpage we will need to scrap.
#
# http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/
#
# ![title](./../../img/FastTrackWebPage.png)

# %% [markdown]
# ![title](./../../img/FastTrackWebPageOutput.png)

# %% [markdown]
# NOTE: All 100 results are contained within rows in <tr> elements and these are all visible on the one page. This will not always be the case and when results span over many pages you may need to either change the number of results displayed on a webpage, or loop over all pages to gather all the information.

# %% [markdown]
# NOTE: Another check that can be done is to check whether a HTTP GET request is being made on the website which may already return the results as structured response such as a JSON or XML format. You can check this from within the network tab in the inspect tools, often in the XHR tab. Once a page is refreshed it will display the requests as they are loaded and if the response contains a formatted structure, it is often easier to make a request using a REST Client such as Insomnia to return the output.

# %%
# installing BeautifulSoup - uncomment the line below to proceed to its installation.
#! pip3 install BeautifulSoup4

# %%
# import libraries
from bs4 import BeautifulSoup
import urllib.request
import csv

# %%
# specify the url
urlpage =  'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)

# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %% [markdown]
# NOTE:  the `html.parser` is the parser included with the Python standard library, though other parsers can be used by Beautiful Soup. See [differences between parsers](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#differences-between-parsers) to learn more.)

# %%
print(soup)
# Out:
# <!-- Template Name: League Table page
# -->
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if gt IE 9]><!--><html class="no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"><!--<![endif]-->
# <!-- the "no-js" class is for Modernizr. -->
# <head id="live2-fasttrack-com"><link data-minify="1" href="http://www.fasttrack.co.uk/wp-content/cache/min/1/e6fd2bd36052429c415bff0bc306fc34.css" rel="stylesheet"/>
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>
# 		League table - Fast Track	</title>
# <meta content="League table - Fast Track" name="title"/>
# <meta content="" name="description"/>
# <meta content="" name="keyword"/>
# <meta content="ZYBMlezF37FAeJwYQIBdbJtogbNm9zRcb4fCelYavj8" name="google-site-verification">
# <!-- Speaking of Google, don't forget to set your site up: http://google.com/webmasters -->
# <!-- Start of Google Analytics Code -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-37401296-1', 'auto');
# ga('set', 'anonymizeIp', true);
#   ga('send', 'pageview');
#
# </script>
# <!-- End of Google Analytics Code -->
# <meta content="Fast Track" name="author"/>
# <meta content="Copyright Fast Track 2011. All Rights Reserved." name="Copyright"/>
# <!-- Dublin Core Metadata : http://dublincore.org/ -->
# <meta content="Fast Track" name="DC.title"/>
# <!--	<meta name="DC.subject" content="What you're about.">-->
# <meta content="TWK" name="DC.creator"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel="stylesheet" type="text/css"/>
# <!-- CSS: screen, mobile & print are all in the same file -->
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/owl.carousel.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/magnific-popup.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/unslider.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/tsort.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/slick.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/slick-theme.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/screen.css" rel="stylesheet"/>
# <link href="http://www.fasttrack.co.uk/xmlrpc.php" rel="pingback">
# <style type="text/css">
#
# 		.hiring-link {
# 			display: inline-block;
# 			position: relative;
# 			top: -23px;
# 			margin-right: 15px;
# 		}
#
# 		.hiring-link span a {
# 			color: white;
# 			font-size: 1.2em;
# 		}
#
# 		.hiring-link span a:hover {
# 			color: #b1b1b1;
# 		}
#
# 		@media only screen and (max-width: 700px) {
# 			.hiring-link {display: none;}
# 		}
#
# 		#wrap-search input[type="text"]:focus {
# 			background: black !important;
# 		}
#
# 	</style>
# <!-- ADD GA CODE HERE -->
# <!-- This site is optimized with the Yoast SEO plugin v6.3 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" rel="canonical">
# <meta content="en_GB" property="og:locale">
# <meta content="article" property="og:type">
# <meta content="League table - Fast Track" property="og:title">
# <meta content="http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" property="og:url">
# <meta content="Fast Track" property="og:site_name">
# <meta content="summary" name="twitter:card">
# <meta content="League table - Fast Track" name="twitter:title">
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"WebSite","@id":"#website","url":"http:\/\/www.fasttrack.co.uk\/","name":"Fast Track","potentialAction":{"@type":"SearchAction","target":"http:\/\/www.fasttrack.co.uk\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//ajax.googleapis.com" rel="dns-prefetch">
# <link href="//s.w.org" rel="dns-prefetch">
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.fasttrack.co.uk\/wp-includes\/js\/wp-emoji-release.min.js?ver=57798d84873bd4552d2d521496da90ed"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var sdm_ajax_script = {"ajaxurl":"http:\/\/www.fasttrack.co.uk\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script src="http://www.fasttrack.co.uk/wp-content/plugins/simple-download-monitor/js/sdm_wp_scripts.js?ver=-b-modified-1524485330" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/modernizr-2.6.2.min.js?ver=-b-modified-1500455178" type="text/javascript"></script>
# <link href="http://www.fasttrack.co.uk/wp-json/" rel="https://api.w.org/">
# <link href="http://www.fasttrack.co.uk/?p=359" rel="shortlink">
# <link href="http://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F" rel="alternate" type="application/json+oembed">
# <link href="http://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F&amp;format=xml" rel="alternate" type="text/xml+oembed">
# <style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style>
# <link href="http://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-66x66.jpg" rel="icon" sizes="32x32">
# <link href="http://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="icon" sizes="192x192">
# <link href="http://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="apple-touch-icon-precomposed">
# <meta content="http://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" name="msapplication-TileImage">
# </meta></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></link></link></meta></head>
# <body class="page-template page-template-page-league-table page-template-page-league-table-php page page-id-359 page-child parent-pageid-159">
# <div id="page-wrap"><!-- not needed? up to you: http://camendesign.com/code/developpeurs_sans_frontieres -->
# <header id="header">
# <nav class="navbar navbar-fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand active hidden-md hidden-lg" href="http://www.fasttrack.co.uk">Tech Track 100</a>
# <a class="navbar-brand fast-track active hidden-sm hidden-xs" href="http://www.fasttrack.co.uk">FAST TRACK</a>
# <div class="navbar-right">
# <div id="wrap-search">
# <form action="http://www.fasttrack.co.uk" autocomplete="on" id="searchform" method="get" name="searchbar_form">
# <input name="post_type[]" type="hidden" value="company_profile"/>
# <input id="search" name="s" placeholder="Company search..." type="text"/><input id="search_submit" type="submit" value="Rechercher"/>
# </form>
# </div>
# <div id="menu_button"><span></span></div>
# </div>
# <div id="side_menu">
# <ul>
# <li><a href="http://www.fasttrack.co.uk/">Home</a>
# </li>
# <li><a href="http://www.fasttrack.co.uk/blog/">News</a>
# </li>
# <li>League tables					  <ul>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/">SME Export Track 100</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/awards/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/">Tech Track 100</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">Ones to Watch</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">Alumni dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/">Fast Track 100</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/awards-dinners/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/ones-to-watch/">Disruptors/Ones to Watch</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/alumni/">Alumni dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/">International Track 200</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/awards-dinners/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/alumni/">Alumni dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/">Profit Track 100</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/awards-dinners/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/ones-to-watch/">Ones to Watch</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/alumni/">Alumni dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/">Top Track 250</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/awards/">Awards dinner</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/top-track-250-ones-to-watch/">Ones to Watch</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/alumni/">Alumni dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/">Top Track 100</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/">Overview</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/league-table/">League table</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/awards/">Directors' dinners</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/about-us/">About us</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/about-us/"></a></li>
# <li><a href="http://www.fasttrack.co.uk/about-us/the-team/">The team</a></li>
# <li><a href="http://www.fasttrack.co.uk/about-us/careers/">Careers</a></li>
# <li><a href="http://www.fasttrack.co.uk/about-us/charity/">Charity</a></li>
# <li><a href="http://www.fasttrack.co.uk/about-us/data-partners/">Data partners</a></li>
# </ul> </li>
# <li><a href="http://www.fasttrack.co.uk/about-us/careers/">Careers</a>
# </li>
# <li><a href="http://www.fasttrack.co.uk/nominate-a-company/">Nominate a company</a>
# </li>
# <li><a href="http://www.fasttrack.co.uk/sponsorship/">Sponsorship</a>
# </li>
# <li class="menu-dropdown"><a href="http://www.fasttrack.co.uk/media-centre/">Media and logos</a>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/media-centre/">Videos</a></li>
# <li><a href="http://www.fasttrack.co.uk/media-centre/press-releases/">Press releases</a></li>
# <li><a href="http://www.fasttrack.co.uk/media-centre/downloads/">Downloads and logos</a></li>
# </ul> </li>
# <li><a href="http://www.fasttrack.co.uk/contact-us/">Contact us</a>
# </li>
# </ul>
# <a href="https://www.linkedin.com/company/sunday-times-fast-track" target="_blank"><img alt="linkedIn" src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/linkedin_circle_icon.png"/></a>
# <a href="https://twitter.com/ST_FastTrack" target="_blank"><img alt="twitter" src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/twitter_circle_icon.png"/></a>
# </div>
# </div>
# </nav>
# </header>
# <div id="content-wrap">
# <section class="subpage-header hidden-xs hidden-sm">
# <div class="main-title-header">
#
# 	Tech Track 100
# 	</div>
# <div class="container"><div class="row">
# <div class="col-sm-4"><img src="http://www.fasttrack.co.uk/wp-content/uploads/TechTrack100-logo-masthead1.png"/></div>
# <div class="col-sm-8 text-right">
# <div class="title_sponsor">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/hiscox/">
# <div class="image" style="background-image: url('http://www.fasttrack.co.uk/wp-content/uploads/Hiscox-logo-1.png');"></div></a>
# </div>
# <div class="supported">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/barclays/">
# <div class="image" style="background-image: url('http://www.fasttrack.co.uk/wp-content/uploads/Barclays-logo-1.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/bdo/">
# <div class="image" style="background-image: url('http://www.fasttrack.co.uk/wp-content/uploads/BDO-logo-1.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/bgf/">
# <div class="image" style="background-image: url('http://www.fasttrack.co.uk/wp-content/uploads/bgf.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/n1-singer/">
# <div class="image" style="background-image: url('http://www.fasttrack.co.uk/wp-content/uploads/n1singer.png');" title=""></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="league_navigation">
# <div class="mobile-league-btn">Menu</div>
# <ul>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/">Overview</a></li>
# <li><a class="active" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">League table</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">Awards dinner</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">Ones to Watch</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">Alumni dinners</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a class="" href="http://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </div>
# </section>
# <div class="container">
# <article class="post" id="post-359">
# <h2>Tech Track 100 league table <div class="dropdown">
# <button class="dropbtn button skew_forward">2018</button>
# <div class="dropdown-content">
# <a href="?leagueyear=2018">2018</a>
# <a href="?leagueyear=2017">2017</a>
# <a href="?leagueyear=2016">2016</a>
# <a href="?leagueyear=2015">2015</a>
# <a href="?leagueyear=2014">2014</a>
# <a href="?leagueyear=2013">2013</a>
# <a href="?leagueyear=2012">2012</a>
# <a href="?leagueyear=2011">2011</a>
# <a href="?leagueyear=2010">2010</a>
# <a href="?leagueyear=2009">2009</a>
# <a href="?leagueyear=2008">2008</a>
# <a href="?leagueyear=2007">2007</a>
# <a href="?leagueyear=2006">2006</a>
# <a href="?leagueyear=2005">2005</a>
# <a href="?leagueyear=2004">2004</a>
# <a href="?leagueyear=2003">2003</a>
# <a href="?leagueyear=2002">2002</a>
# <a href="?leagueyear=2001">2001</a>
# </div>
# </div>
# </h2>
# </article>
# <!--				Pull in data from the current year selected in page -->
# <div class="responsive-tabble-wrapper">
# <table class="tableSorter">
# <tbody>
# <tr>
# <th>Rank</th>
# <th>Company</th>
# <th class="">Location</th>
# <th class="no-word-wrap">Year end</th>
# <th class="" style="text-align:right;">Annual sales rise over 3 years</th>
# <th class="" style="text-align:right;">Latest sales £000s</th>
# <th class="" style="text-align:right;">Staff</th>
# <th class="">Comment</th>
# <!--				<th>FYE</th>-->
# </tr>
# <tr>
# <td>1</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/plan-com/"><span class="company-name">Plan.com</span></a>Communications provider</td>
# <td>Isle of Man</td>
# <td>Sep-17</td>
# <td style="text-align:right;">364.38%</td>
# <td style="text-align:right;">*35,418</td>
# <td style="text-align:right;">90</td>
# <td>About 650 partners use its telecoms platform to support more than 100,000 UK business customers</td>
# <!--						<td>Sep-17</td>-->
# </tr>
# <tr>
# <td>2</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/psioxus-2/"><span class="company-name">PsiOxus</span></a>Biotechnology developer</td>
# <td>Oxfordshire</td>
# <td>Dec-17</td>
# <td style="text-align:right;">311.67%</td>
# <td style="text-align:right;">53,136</td>
# <td style="text-align:right;">54</td>
# <td>Received a $15m milestone payment from its development partner Bristol-Myers Squibb in December</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>3</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/censornet/"><span class="company-name">CensorNet</span></a>Cloud security software developer</td>
# <td>Basingstoke</td>
# <td>Dec-17</td>
# <td style="text-align:right;">210.17%</td>
# <td style="text-align:right;">*7,535</td>
# <td style="text-align:right;">77</td>
# <td>Has more than 4,000 customers, including McDonald’s in France and the European Central Bank</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>4</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/thoughtonomy/"><span class="company-name">thoughtonomy</span></a>Automation software developer</td>
# <td>East London</td>
# <td>May-18</td>
# <td style="text-align:right;">205.20%</td>
# <td style="text-align:right;">*16,916</td>
# <td style="text-align:right;">100</td>
# <td>It sells to 28 countries and 50% of revenue is generated from overseas</td>
# <!--						<td>May-18</td>-->
# </tr>
# <tr>
# <td>5</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/perkbox-2/"><span class="company-name">Perkbox</span></a>Employee engagement services</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">204.12%</td>
# <td style="text-align:right;">*34,700</td>
# <td style="text-align:right;">200</td>
# <td>Acquired software platform Loyalty Bay for an undisclosed sum in November</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>6</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/ogury/"><span class="company-name">Ogury</span></a>Mobile data marketing</td>
# <td>North London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">204.09%</td>
# <td style="text-align:right;">33,760</td>
# <td style="text-align:right;">133</td>
# <td>It has access to data from more than 400m mobile phone users in 120 countries</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>7</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/verve/"><span class="company-name">Verve</span></a>Marketing software developer</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">202.15%</td>
# <td style="text-align:right;">*10,747</td>
# <td style="text-align:right;">130</td>
# <td>Its network of 25,000 ‘micro-influencers’ have sold half a million event tickets since 2014</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>8</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/gohenry/"><span class="company-name">goHenry</span></a>Children's pre-paid card developer</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">200.87%</td>
# <td style="text-align:right;">*6,116</td>
# <td style="text-align:right;">61</td>
# <td>The company is named after the first child to make a transaction with one of its cards</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>9</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/darktrace-3/"><span class="company-name">Darktrace</span></a>Cybersecurity developer</td>
# <td>Cambridge</td>
# <td>Jun-18</td>
# <td style="text-align:right;">195.51%</td>
# <td style="text-align:right;">*58,573</td>
# <td style="text-align:right;">694</td>
# <td>Was reportedly valued at $1.25bn in April when Vitruvian Partners bought a small stake</td>
# <!--						<td>Jun-18</td>-->
# </tr>
# <tr>
# <td>10</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/bizuma/"><span class="company-name">Bizuma</span></a>B2B e-commerce platform</td>
# <td>Central London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">181.75%</td>
# <td style="text-align:right;">*9,608</td>
# <td style="text-align:right;">48</td>
# <td>Originally founded as a flash sales website before changing direction in 2014</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>11</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/depop/"><span class="company-name">Depop</span></a>Social shopping app</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">175.70%</td>
# <td style="text-align:right;">*94,300</td>
# <td style="text-align:right;">95</td>
# <td>More than 10m people use its platform to buy and sell vintage clothing</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>12</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/laser-wire-solutions/"><span class="company-name">Laser Wire Solutions</span></a>Laser wire-stripping machinery</td>
# <td>Pontypridd</td>
# <td>Dec-17</td>
# <td style="text-align:right;">173.41%</td>
# <td style="text-align:right;">*5,114</td>
# <td style="text-align:right;">26</td>
# <td>Swiss technology group Schleuniger took a 20% stake in 2016</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>13</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/bought-by-many-2/"><span class="company-name">Bought By Many</span></a>Specialist insurance platform</td>
# <td>Central London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">170.20%</td>
# <td style="text-align:right;">*19,727</td>
# <td style="text-align:right;">78</td>
# <td>Launched its own travel insurance policy for people with severe medical conditions in December</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>14</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/optal-5/"><span class="company-name">Optal</span></a>Payment services provider</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">169.29%</td>
# <td style="text-align:right;">177,653</td>
# <td style="text-align:right;">65</td>
# <td>Uses the Mastercard processing network to facilitate payments in 34 currencies</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>15</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/infinox-2/"><span class="company-name">Infinox</span></a>Currency trading platform</td>
# <td>Central London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">155.18%</td>
# <td style="text-align:right;">*41,700</td>
# <td style="text-align:right;">48</td>
# <td>Provides users with an AI-generated news feed that could affect currency trades</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>16</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/oakbrook-2/"><span class="company-name">Oakbrook</span></a>Consumer finance provider</td>
# <td>Nottingham</td>
# <td>Dec-17</td>
# <td style="text-align:right;">154.54%</td>
# <td style="text-align:right;">*40,400</td>
# <td style="text-align:right;">98</td>
# <td>Uses machine learning to help estimate borrowers’ credit risk</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>17</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/carwow/"><span class="company-name">Carwow</span></a>Car sales platform</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">147.21%</td>
# <td style="text-align:right;">*15,276</td>
# <td style="text-align:right;">127</td>
# <td>Claims its car review videos have more viewers than the hit BBC series Top Gear</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>18</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/receipt-bank-2/"><span class="company-name">Receipt Bank</span></a>Book-keeping automation services</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">146.07%</td>
# <td style="text-align:right;">*11,667</td>
# <td style="text-align:right;">341</td>
# <td>Says 150,000 businesses in America, Europe and Australia use its book-keeping software</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>19</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/db-broadcast-2/"><span class="company-name">dB Broadcast</span></a>Broadcast technology provider</td>
# <td>Cambridgeshire</td>
# <td>Sep-17</td>
# <td style="text-align:right;">143.58%</td>
# <td style="text-align:right;">34,943</td>
# <td style="text-align:right;">50</td>
# <td>Its key customers include Sky, YouTube, Bloomberg and the BBC</td>
# <!--						<td>Sep-17</td>-->
# </tr>
# <tr>
# <td>20</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/the-car-buying-group/"><span class="company-name">The Car Buying Group</span></a>Car sales platform</td>
# <td>Wakefield</td>
# <td>Mar-18</td>
# <td style="text-align:right;">140.89%</td>
# <td style="text-align:right;">*39,140</td>
# <td style="text-align:right;">31</td>
# <td>Runs a free nationwide doorstep vehicle collection service</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>21</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/festicket-2/"><span class="company-name">Festicket</span></a>Festival booking platform</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">139.86%</td>
# <td style="text-align:right;">35,839</td>
# <td style="text-align:right;">88</td>
# <td>Sells tickets and packages to more than 1,000 festivals worldwide</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>22</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/planixs/"><span class="company-name">Planixs</span></a>Software developer</td>
# <td>Manchester</td>
# <td>Mar-17</td>
# <td style="text-align:right;">133.70%</td>
# <td style="text-align:right;">*7,240</td>
# <td style="text-align:right;">67</td>
# <td>More than £200bn worth of transactions have been analysed using its systems</td>
# <!--						<td>Mar-17</td>-->
# </tr>
# <tr>
# <td>23</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/gigaclear/"><span class="company-name">Gigaclear</span></a>Internet services provider</td>
# <td>Oxfordshire</td>
# <td>Dec-17</td>
# <td style="text-align:right;">130.17%</td>
# <td style="text-align:right;">7,402</td>
# <td style="text-align:right;">210</td>
# <td>Has connected more than 16,000 rural customers to broadband in 22 counties</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>24</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/transferwise-4/"><span class="company-name">TransferWise</span></a>Currency transfer provider</td>
# <td>East London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">129.39%</td>
# <td style="text-align:right;">*117,283</td>
# <td style="text-align:right;">1000</td>
# <td>Was valued at $1.6bn in November after it raised $280m, taking its funding total to $396m</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>25</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/patsnap/"><span class="company-name">PatSnap</span></a>R&amp;D; data platform</td>
# <td>West London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">126.18%</td>
# <td style="text-align:right;">*17,977</td>
# <td style="text-align:right;">752</td>
# <td>Has raised more than $100m from investors including Sequoia and Shunwei Capital</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>26</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/hyperoptic-2/"><span class="company-name">Hyperoptic</span></a>Internet services provider</td>
# <td>West London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">119.90%</td>
# <td style="text-align:right;">16,572</td>
# <td style="text-align:right;">411</td>
# <td>Aims to provide superfast broadband to more than 2m homes by 2022</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>27</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/gocardless-2/"><span class="company-name">GoCardless</span></a>Payment services provider</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">112.99%</td>
# <td style="text-align:right;">*11,896</td>
# <td style="text-align:right;">165</td>
# <td>International expansion plans include targeting Australia, New Zealand, Canada and the US</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>28</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/purple/"><span class="company-name">Purple</span></a>Wifi services provider</td>
# <td>Oldham</td>
# <td>Jan-18</td>
# <td style="text-align:right;">112.88%</td>
# <td style="text-align:right;">*5,586</td>
# <td style="text-align:right;">93</td>
# <td>Its technology is used in every public airport in Spain and in a 21,000-capacity stadium in Miami</td>
# <!--						<td>Jan-18</td>-->
# </tr>
# <tr>
# <td>29</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/trustpay-global/"><span class="company-name">Trustpay Global</span></a>Online payment provider</td>
# <td>Guildford</td>
# <td>Mar-18</td>
# <td style="text-align:right;">110.45%</td>
# <td style="text-align:right;">*9,796</td>
# <td style="text-align:right;">25</td>
# <td>The Premier Lotto in Nigeria uses the company’s platform to prevent money laundering</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>30</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/iwoca-2/"><span class="company-name">iwoca</span></a>Business finance provider</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">109.27%</td>
# <td style="text-align:right;">*25,000</td>
# <td style="text-align:right;">200</td>
# <td>Its 140 employees include three former Olympians</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>31</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/ladbible-group-2/"><span class="company-name">LADBible Group</span></a>Online entertainment community</td>
# <td>Manchester</td>
# <td>Dec-17</td>
# <td style="text-align:right;">108.91%</td>
# <td style="text-align:right;">*15,500</td>
# <td style="text-align:right;">133</td>
# <td>Claims its flagship brand reaches more than half of all millennials in the UK every month</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>32</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/threads-styling-2/"><span class="company-name">Threads Styling</span></a>Online fashion services</td>
# <td>East London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">107.88%</td>
# <td style="text-align:right;">*12,672</td>
# <td style="text-align:right;">55</td>
# <td>Some three-quarters of its sales are to fashionistas in the Middle East</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>33</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/prodigy-finance-2/"><span class="company-name">Prodigy Finance</span></a>Student finance provider</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">105.94%</td>
# <td style="text-align:right;">*10,273</td>
# <td style="text-align:right;">133</td>
# <td>More than 10,000 students have used its platform to fund their postgraduate studies</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>34</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/azimo/"><span class="company-name">Azimo</span></a>Online money transfers</td>
# <td>Central London</td>
# <td>Jun-17</td>
# <td style="text-align:right;">103.79%</td>
# <td style="text-align:right;">5,870</td>
# <td style="text-align:right;">115</td>
# <td>Recently launched its international money transfer service for businesses</td>
# <!--						<td>Jun-17</td>-->
# </tr>
# <tr>
# <td>35</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/chameleon-2/"><span class="company-name">Chameleon</span></a>Smart energy monitoring</td>
# <td>Harrogate</td>
# <td>Dec-17</td>
# <td style="text-align:right;">101.10%</td>
# <td style="text-align:right;">19,890</td>
# <td style="text-align:right;">32</td>
# <td>About 2.5m of its energy display units have been installed in UK homes</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>36</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/superawesome-2/"><span class="company-name">SuperAwesome</span></a>Children's privacy protection</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">97.91%</td>
# <td style="text-align:right;">*14,935</td>
# <td style="text-align:right;">130</td>
# <td>Last month it signed a deal with Pokémon Go, allowing parents to manage their child’s privacy settings</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>37</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/gousto/"><span class="company-name">Gousto</span></a>Meal kit delivery services</td>
# <td>West London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">97.32%</td>
# <td style="text-align:right;">*23,300</td>
# <td style="text-align:right;">400</td>
# <td>Aims to provide the ingredients for 400m meals in UK homes by 2025</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>38</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/vizolution/"><span class="company-name">Vizolution</span></a>Business software developer</td>
# <td>Swansea</td>
# <td>Dec-17</td>
# <td style="text-align:right;">94.99%</td>
# <td style="text-align:right;">*6,965</td>
# <td style="text-align:right;">118</td>
# <td>Its DigiDocs software lets RBS customers complete mortgage applications digitally</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>39</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/movegb/"><span class="company-name">MoveGB</span></a>Activity membership</td>
# <td>Bath</td>
# <td>Dec-17</td>
# <td style="text-align:right;">94.93%</td>
# <td style="text-align:right;">*5,029</td>
# <td style="text-align:right;">41</td>
# <td>Has 300,000 subscribers gaining access to more than 6,000 fitness venues</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>40</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/bboxx-3/"><span class="company-name">BBOXX</span></a>Solar system manufacturer</td>
# <td>West London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">93.35%</td>
# <td style="text-align:right;">*20,416</td>
# <td style="text-align:right;">443</td>
# <td>Has raised almost $70m in venture funding and debt financing</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>41</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/funding-circle-4/"><span class="company-name">Funding Circle</span></a>Peer-to-peer lending platform</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">93.21%</td>
# <td style="text-align:right;">*94,500</td>
# <td style="text-align:right;">790</td>
# <td>Is planning an IPO in London this autumn that will value it at more than £1.5bn </td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>42</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/loopme-2/"><span class="company-name">LoopMe</span></a>Advertising technology developer</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">93.04%</td>
# <td style="text-align:right;">24,493</td>
# <td style="text-align:right;">91</td>
# <td>Says its AI technology reaches 2bn devices around the world</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>43</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/kano-3/"><span class="company-name">Kano</span></a>Educational computer developer</td>
# <td>East London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">91.81%</td>
# <td style="text-align:right;">*13,000</td>
# <td style="text-align:right;">60</td>
# <td>Has customers in 150 countries and aims to have 100m global users by 2020</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>44</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/capital-on-tap-2/"><span class="company-name">Capital on Tap</span></a>Business finance provider</td>
# <td>West London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">88.73%</td>
# <td style="text-align:right;">17,318</td>
# <td style="text-align:right;">56</td>
# <td>This company’s founders also set up Paymentsense, No 91 in the league table</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>45</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/hutch/"><span class="company-name">Hutch</span></a>Video games developer</td>
# <td>Central London</td>
# <td>Sep-17</td>
# <td style="text-align:right;">88.63%</td>
# <td style="text-align:right;">*8,766 (2017)</td>
# <td style="text-align:right;">51</td>
# <td>Its Hot Wheels Race Off game has been played in 190 countries including Antarctica and Vatican City</td>
# <!--						<td>Sep-17</td>-->
# </tr>
# <tr>
# <td>46</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/ensek/"><span class="company-name">ENSEK</span></a>Energy software developer</td>
# <td>Nottingham</td>
# <td>Mar-18</td>
# <td style="text-align:right;">87.56%</td>
# <td style="text-align:right;">*6,161</td>
# <td style="text-align:right;">110</td>
# <td>A fifth of the UK’s energy suppliers are said to use this company’s software</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>47</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/miq-3/"><span class="company-name">MiQ</span></a>Digital marketing agency</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">87.36%</td>
# <td style="text-align:right;">*155,876</td>
# <td style="text-align:right;">561</td>
# <td>Relocated its New York base in April, tripling its office space</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>48</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/starleaf-2/"><span class="company-name">StarLeaf</span></a>Video conferencing platform</td>
# <td>Watford</td>
# <td>Dec-17</td>
# <td style="text-align:right;">86.89%</td>
# <td style="text-align:right;">11,427</td>
# <td style="text-align:right;">133</td>
# <td>Its founders set up the Tech Track 100 alumnus Codian and sold it for $270m in 2007</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>49</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/bigchange/"><span class="company-name">BigChange</span></a>Management software developer</td>
# <td>Leeds</td>
# <td>Dec-17</td>
# <td style="text-align:right;">86.45%</td>
# <td style="text-align:right;">*6,566</td>
# <td style="text-align:right;">41</td>
# <td>Last year its technology saved 15m sheets of paper and facilitated 9m tasks</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>50</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/the-lead-agency/"><span class="company-name">The Lead Agency</span></a>Lead generation developer</td>
# <td>Liverpool</td>
# <td>Dec-17</td>
# <td style="text-align:right;">80.38%</td>
# <td style="text-align:right;">†6,383</td>
# <td style="text-align:right;">96</td>
# <td>Works with every large automotive brand in the UK</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>51</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/unidays-3/"><span class="company-name">UNiDAYS</span></a>Student verification services</td>
# <td>Nottingham</td>
# <td>Apr-18</td>
# <td style="text-align:right;">80.03%</td>
# <td style="text-align:right;">*27,400</td>
# <td style="text-align:right;">210</td>
# ...
# <td>North Yorkshire</td>
# <td>Mar-17</td>
# <td style="text-align:right;">59.56%</td>
# <td style="text-align:right;">7,161</td>
# <td style="text-align:right;">86</td>
# <td>Appointed the former European boss of American Express to drive sales on the continent</td>
# <!--						<td>Mar-17</td>-->
# </tr>
# <tr>
# <td>79</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/pm-connect-2/"><span class="company-name">PM Connect</span></a>Mobile content provider</td>
# <td>Birmingham</td>
# <td>Feb-18</td>
# <td style="text-align:right;">59.44%</td>
# <td style="text-align:right;">*19,317</td>
# <td style="text-align:right;">35</td>
# <td>Its clients include World Wrestling Entertainment and the NBA</td>
# <!--						<td>Feb-18</td>-->
# </tr>
# <tr>
# <td>80</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/zopa-5/"><span class="company-name">Zopa</span></a>Peer-to-peer lending platform</td>
# <td>South London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">59.43%</td>
# <td style="text-align:right;">*46,500</td>
# <td style="text-align:right;">312</td>
# <td>About £3.5bn has been advanced through its platform</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>81</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/worldremit-3/"><span class="company-name">WorldRemit</span></a>Online money transfers</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">59.07%</td>
# <td style="text-align:right;">*61,000</td>
# <td style="text-align:right;">440</td>
# <td>Has raised $220m since 2010 to expand its online money transfer service</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>82</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/dianomi-3/"><span class="company-name">Dianomi</span></a>Financial content marketing</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">58.99%</td>
# <td style="text-align:right;">*12,861</td>
# <td style="text-align:right;">25</td>
# <td>Works with eight of the top 10 global asset managers</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>83</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/liberis/"><span class="company-name">Liberis</span></a>Cash advance provider</td>
# <td>West London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">57.99%</td>
# <td style="text-align:right;">*15,150</td>
# <td style="text-align:right;">75</td>
# <td>Received £57.5m in funding in April from investors including Blenheim Chalcot</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>84</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/currencycloud/"><span class="company-name">Currencycloud</span></a>Payment services provider</td>
# <td>East London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">57.48%</td>
# <td style="text-align:right;">*13,600</td>
# <td style="text-align:right;">140</td>
# <td>Has 250 clients and 2m end users across the world</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>85</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/featurespace/"><span class="company-name">Featurespace</span></a>Analytics software developer</td>
# <td>Cambridge</td>
# <td>Dec-17</td>
# <td style="text-align:right;">57.48%</td>
# <td style="text-align:right;">*5,170</td>
# <td style="text-align:right;">113</td>
# <td>Is recruiting for more than 100 positions this year, following customer demand in UK and US</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>86</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/cloud-technology-solutions-3/"><span class="company-name">Cloud Technology Solutions</span></a>Cloud IT developer</td>
# <td>Manchester</td>
# <td>Mar-18</td>
# <td style="text-align:right;">57.21%</td>
# <td style="text-align:right;">*21,902</td>
# <td style="text-align:right;">102</td>
# <td>Its software has moved nearly 12,000 companies in 20 countries onto Google Apps</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>87</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/leisure-pass-group-3/"><span class="company-name">Leisure Pass Group</span></a>Tourism smartcard developer</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">57.16%</td>
# <td style="text-align:right;">†225,803</td>
# <td style="text-align:right;">105</td>
# <td>Has partnered with the booking platform Ctrip to target Chinese tourists visiting Europe</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>88</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/rradar/"><span class="company-name">rradar</span></a>Legal digital services</td>
# <td>Hull</td>
# <td>Dec-17</td>
# <td style="text-align:right;">57.03%</td>
# <td style="text-align:right;">*5,083</td>
# <td style="text-align:right;">125</td>
# <td>Uses machine learning and AI to provide legal advice to customers</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>89</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/converge-ts/"><span class="company-name">Converge TS</span></a>Cloud services provider</td>
# <td>Cheshire</td>
# <td>Dec-17</td>
# <td style="text-align:right;">55.00%</td>
# <td style="text-align:right;">*5,802</td>
# <td style="text-align:right;">38</td>
# <td>Focused solely on the legal sector after its first three clients were all law firms</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>90</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/kimble-applications-2/"><span class="company-name">Kimble Applications</span></a>Software developer</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">54.67%</td>
# <td style="text-align:right;">*9,153</td>
# <td style="text-align:right;">78</td>
# <td>More than half of its new business is in the US, where it has offices in Boston and Park City</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>91</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/paymentsense-8/"><span class="company-name">Paymentsense</span></a>Payment services provider</td>
# <td>West London</td>
# <td>Mar-18</td>
# <td style="text-align:right;">53.54%</td>
# <td style="text-align:right;">*72,400</td>
# <td style="text-align:right;">243</td>
# <td>Processed more than £6.5bn of card payments last year in the UK and Ireland</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>92</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/godel-technologies-2/"><span class="company-name">Godel Technologies</span></a>Software developer</td>
# <td>Manchester</td>
# <td>Dec-17</td>
# <td style="text-align:right;">53.01%</td>
# <td style="text-align:right;">*13,853</td>
# <td style="text-align:right;">637</td>
# <td>Is named after the late German mathematician Kurt Gödel</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>93</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/secret-escapes-2/"><span class="company-name">Secret Escapes</span></a>Online travel services</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">52.99%</td>
# <td style="text-align:right;">*73,000</td>
# <td style="text-align:right;">850</td>
# <td>Has raised £132m from investors including Google Ventures</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>94</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/neuven-4/"><span class="company-name">Neuven</span></a>HR software developer</td>
# <td>Manchester</td>
# <td>Jul-17</td>
# <td style="text-align:right;">52.23%</td>
# <td style="text-align:right;">130,071</td>
# <td style="text-align:right;">28</td>
# <td>Appearing on Tech Track 100 for a fourth consecutive year</td>
# <!--						<td>Jul-17</td>-->
# </tr>
# <tr>
# <td>95</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/citnow-3/"><span class="company-name">CitNOW</span></a>Video software developer</td>
# <td>Wokingham</td>
# <td>Dec-17</td>
# <td style="text-align:right;">51.85%</td>
# <td style="text-align:right;">*11,611</td>
# <td style="text-align:right;">71</td>
# <td>Has more than 8,000 installations in franchised car dealerships in 45 countries</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>96</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/geo-2/"><span class="company-name">geo</span></a>Smart energy monitoring</td>
# <td>Cambridge</td>
# <td>Mar-18</td>
# <td style="text-align:right;">51.24%</td>
# <td style="text-align:right;">*29,406</td>
# <td style="text-align:right;">85</td>
# <td>Customers in Norway, Sweden and Luxembourg use its smart energy monitoring devices</td>
# <!--						<td>Mar-18</td>-->
# </tr>
# <tr>
# <td>97</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/vision-rt/"><span class="company-name">Vision RT</span></a>Medical technology developer</td>
# <td>North London</td>
# <td>Jul-17</td>
# <td style="text-align:right;">50.99%</td>
# <td style="text-align:right;">32,468</td>
# <td style="text-align:right;">132</td>
# <td>Has secured 60 patents and has another 46 pending</td>
# <!--						<td>Jul-17</td>-->
# </tr>
# <tr>
# <td>98</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/thread/"><span class="company-name">Thread</span></a>Online fashion services</td>
# <td>Central London</td>
# <td>Dec-17</td>
# <td style="text-align:right;">50.77%</td>
# <td style="text-align:right;">*6,492</td>
# <td style="text-align:right;">60</td>
# <td>More than 800,000 men subscribe to its free personal styling service</td>
# <!--						<td>Dec-17</td>-->
# </tr>
# <tr>
# <td>99</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/the-media-image-4/"><span class="company-name">The Media Image</span></a>Digital marketing agency</td>
# <td>South London</td>
# <td>Feb-18</td>
# <td style="text-align:right;">50.38%</td>
# <td style="text-align:right;">*27,515</td>
# <td style="text-align:right;">37</td>
# <td>Founded by the man who was Google UK’s first recruit when it launched its AdWords service in 2002</td>
# <!--						<td>Feb-18</td>-->
# </tr>
# <tr>
# <td>100</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/brompton-technology/"><span class="company-name">Brompton Technology</span></a>Video technology provider</td>
# <td>West London</td>
# <td>Aug-17</td>
# <td style="text-align:right;">50.17%</td>
# <td style="text-align:right;">*5,250</td>
# <td style="text-align:right;">27</td>
# <td>Its technology is used in high-profile events such as the Oscars</td>
# <!--						<td>Aug-17</td>-->
# </tr>
# </tbody>
# </table> </div>
# <div class="row"><div class="col-md-8 legend"><p><span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'>* supplied by company  </span>†<span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'> annualised figure</span></p>
# </div></div>
# </div>
# <section class="normal-padding hidden-md hidden-lg">
# <div class="container"><div class="row">
# <h2>Sponsors</h2>
# <div class="col-xs-6">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/hiscox/"><img src="http://www.fasttrack.co.uk/wp-content/uploads/Hiscox-logo-1.png"/>
# </a>
# </div>
# <div class="col-xs-6">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/barclays/"><img src="http://www.fasttrack.co.uk/wp-content/uploads/Barclays-logo-1.png"/></a>
# </div>
# <div class="col-xs-6">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/bdo/"><img src="http://www.fasttrack.co.uk/wp-content/uploads/BDO-logo-1.png"/></a>
# </div>
# <div class="col-xs-6">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/bgf/"><img src="http://www.fasttrack.co.uk/wp-content/uploads/bgf.png"/></a>
# </div>
# <div class="col-xs-6">
# <a href="http://www.fasttrack.co.uk/sponsor-profiles/n1-singer/"><img src="http://www.fasttrack.co.uk/wp-content/uploads/n1singer.png"/></a>
# </div>
# </div></div>
# <div class="mobile-only text-center" style="margin-top: 20px;">
# <a class="button skew_forward" href="/league-tables/league-table/sponsorship/">Sponsorship</a>
# </div>
# </section>
# </div>
# </div> <!-- END DIV MAIN CONTENT -->
# <footer class="" id="footer">
# <div class="container">
# <div class="col-sm-3">
# <img class="footer-logo" src="http://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-logo-white-strapline.png"/>
# </div>
# <div class="col-sm-3 col-xs-6">
# <h5>League tables</h5>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/league-tables/sme-export-track-100/">SME Export Track 100</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/tech-track-100/">Tech Track 100</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/fast-track-100/">Fast Track 100</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/international-track-200/">International Track 200</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/profit-track-100/">Profit Track 100</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-250/">Top Track 250</a></li>
# <li><a href="http://www.fasttrack.co.uk/league-tables/top-track-100/">Top Track 100</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <h5>Further info</h5>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/about-us/">About us</a></li>
# <li><a href="http://www.fasttrack.co.uk/nominate-a-company/">Nominate a company</a></li>
# <li><a href="http://www.fasttrack.co.uk/sponsorship/">Sponsorship</a></li>
# <li><a href="http://www.fasttrack.co.uk/media-centre/">Media centre</a></li>
# <li><a href="http://www.fasttrack.co.uk/contact-us/">Contact us</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-12">
# <h5>Other</h5>
# <ul>
# <li><a href="http://www.fasttrack.co.uk/privacy-cookies-policy/">Privacy &amp; cookies policy</a></li>
# <li><a href="http://www.thewebkitchen.co.uk/" target="_blank">Web design</a> by TWK</li>
# </ul>
# </div>
# </div>
# </footer>
# </body></html>
# <script type="text/javascript">
#
# _linkedin_data_partner_id = "323508";
#
# </script><script type="text/javascript">
#
# (function(){var s = document.getElementsByTagName("script")[0];
#
# var b = document.createElement("script");
#
# b.type = "text/javascript";b.async = true;
#
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#
# s.parentNode.insertBefore(b, s);})();
#
# </script>
# <noscript>
# <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=323508&amp;fmt=gif" style="display:none;" width="1">
# </img></noscript>
# <!-- JS ARE LOADED HERE WITH FUNCTION.PHP -->
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/bootstrap.min.js?ver=-b-modified-1500455175" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/owl.carousel.min.js?ver=-b-modified-1500455179" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/slick.js?ver=-b-modified-1500455179" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/jquery.magnific-popup.min.js?ver=-b-modified-1500455177" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/lightbox.js?ver=-b-modified-1500455178" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/script.js?ver=-b-modified-1531151683" type="text/javascript"></script>
# <script src="http://www.fasttrack.co.uk/wp-includes/js/wp-embed.min.js?ver=57798d84873bd4552d2d521496da90ed" type="text/javascript"></script>
# <!-- Wordpress-friendly way via functions.php -->
# <!-- Asynchronous google analytics; this is the official snippet.
# 		 Replace UA-XXXXXX-XX with your site's ID and uncomment to enable.
#
# 	<script>
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-XXXXXX-XX']);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 	    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
# 	-->
#
#
# <!-- Cached page for great performance - Debug: cached@1543249281 -->

# %% [markdown]
# ## Search for HTML Elements
#
# As all of the results are contained within a table, we can search the soup object for the table using the find method. We can then find each row within the table using the find_all method.
#
# If we print the number of rows we should get a result of 101, the 100 rows plus the header.

# %%
# find results within table
table = soup.find('table', attrs={'class': 'tableSorter'})
#print(table)

# find all the table rows (tr)
results = table.find_all('tr')
#print(results)

print('Number of results', len(results))
# Out:
# Number of results 101

# %%
#we can slice the results, to get 3 results
results[0:3]
# Out:
# [<tr>
#  <th>Rank</th>
#  <th>Company</th>
#  <th class="">Location</th>
#  <th class="no-word-wrap">Year end</th>
#  <th class="" style="text-align:right;">Annual sales rise over 3 years</th>
#  <th class="" style="text-align:right;">Latest sales £000s</th>
#  <th class="" style="text-align:right;">Staff</th>
#  <th class="">Comment</th>
#  <!--				<th>FYE</th>-->
#  </tr>, <tr>
#  <td>1</td>
#  <td><a href="http://www.fasttrack.co.uk/company_profile/plan-com/"><span class="company-name">Plan.com</span></a>Communications provider</td>
#  <td>Isle of Man</td>
#  <td>Sep-17</td>
#  <td style="text-align:right;">364.38%</td>
#  <td style="text-align:right;">*35,418</td>
#  <td style="text-align:right;">90</td>
#  <td>About 650 partners use its telecoms platform to support more than 100,000 UK business customers</td>
#  <!--						<td>Sep-17</td>-->
#  </tr>, <tr>
#  <td>2</td>
#  <td><a href="http://www.fasttrack.co.uk/company_profile/psioxus-2/"><span class="company-name">PsiOxus</span></a>Biotechnology developer</td>
#  <td>Oxfordshire</td>
#  <td>Dec-17</td>
#  <td style="text-align:right;">311.67%</td>
#  <td style="text-align:right;">53,136</td>
#  <td style="text-align:right;">54</td>
#  <td>Received a $15m milestone payment from its development partner Bristol-Myers Squibb in December</td>
#  <!--						<td>Dec-17</td>-->
#  </tr>]

# %%
# we can find the last line from the results list
results[-1]
# Out:
# <tr>
# <td>100</td>
# <td><a href="http://www.fasttrack.co.uk/company_profile/brompton-technology/"><span class="company-name">Brompton Technology</span></a>Video technology provider</td>
# <td>West London</td>
# <td>Aug-17</td>
# <td style="text-align:right;">50.17%</td>
# <td style="text-align:right;">*5,250</td>
# <td style="text-align:right;">27</td>
# <td>Its technology is used in high-profile events such as the Oscars</td>
# <!--						<td>Aug-17</td>-->
# </tr>

# %% [markdown]
# We can therefore loop over the results to gather the data.
#
# Printing the first 2 rows in the soup object, we can see that the structure of each row is:

# %%
# nicely printing the first 5 rows using the soup method: prettify()
results = soup.prettify().splitlines()
print('\n''newline'.join(results[:5]))
# Out:
# <!-- Template Name: League Table page
# newline-->
# newline<!DOCTYPE html>
# newline<!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# newline<!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->

# %%
#print the first 10 and the last 10 rows. 
results = soup.prettify().splitlines()
print('\n'.join(results[:10] + results[-10:]))
# Out:
# <!-- Template Name: League Table page
# -->
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en-GB" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#
# 	  (function() {
# 	    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
# 	-->
# <!-- Cached page for great performance - Debug: cached@1543249281 -->

# %%
print(results)
# Out:
# ['<!-- Template Name: League Table page', '-->', '<!DOCTYPE html>', '<!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->', '<!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->', '<!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->', '<!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->', '<!--[if gt IE 9]><!-->', '<html class="no-js" lang="en-GB" prefix="og: http://ogp.me/ns#">', ' <!--<![endif]-->', ' <!-- the "no-js" class is for Modernizr. -->', ' <head id="live2-fasttrack-com">', '  <link data-minify="1" href="http://www.fasttrack.co.uk/wp-content/cache/min/1/e6fd2bd36052429c415bff0bc306fc34.css" rel="stylesheet"/>', '  <meta charset="utf-8"/>', '  <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->', '  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>', '  <title>', '   League table - Fast Track', '  </title>', '  <meta content="League table - Fast Track" name="title"/>', '  <meta content="" name="description"/>', '  <meta content="" name="keyword"/>', '  <meta content="ZYBMlezF37FAeJwYQIBdbJtogbNm9zRcb4fCelYavj8" name="google-site-verification">', "   <!-- Speaking of Google, don't forget to set your site up: http://google.com/webmasters -->", '   <!-- Start of Google Analytics Code -->', '   <script>', "    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){", '  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),', '  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)', "  })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');", '', "  ga('create', 'UA-37401296-1', 'auto');", "ga('set', 'anonymizeIp', true);", "  ga('send', 'pageview');", '   </script>', '   <!-- End of Google Analytics Code -->', '   <meta content="Fast Track" name="author"/>', '   <meta content="Copyright Fast Track 2011. All Rights Reserved." name="Copyright"/>', '   <!-- Dublin Core Metadata : http://dublincore.org/ -->', '   <meta content="Fast Track" name="DC.title"/>', '   <!--\t<meta name="DC.subject" content="What you\'re about.">-->', '   <meta content="TWK" name="DC.creator"/>', '   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>', '   <link href="http://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img ...

# %% [markdown]
# ## Looping through elements and saving variables
# In python, it is useful to append the results to a list to then write the data to a file. We should declare the list and set the headers of the csv before the loop with the following:

# %%
# create and write headers to a list 
rows = []
rows.append(['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'])
print(rows)
# Out:
# [['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments']]

# %% [markdown]
# The code above prints out the first row that we have added to the list containing the headers.
#
# You might notice that there are a few extra fields Webpage and Description which are not column names in the table, but if you take a closer look in the html from when we printed the soup variable above, the second row contains more than just the company name. We can use some further extraction to get this extra information.

# %% [markdown]
# The next step is to loop over the results, process the data and append to rows which can be written to a csv.

# %%
results = table.find_all('tr')
#   Loop over the results
for result in results:
#   Find all columns per result
    data = result.find_all('td')
#   Check that columns have data
    if len(data) == 0:
        continue

# %% [markdown]
# Since the first row in the table contains only the headers, we can skip this result, as shown above. It also does not contain any <td> elements so when searching for the element, nothing is returned. We can then check that only results containing data are processed by requiring the length of the data to be non-zero.

# %% [markdown]
# We can then start to process the data and save to variables.

# %%
# write columns to variables
rank = data[0].getText()
company = data[1].getText()
location = data[2].getText()
yearend = data[3].getText()
salesrise = data[4].getText()
sales = data[5].getText()
staff = data[6].getText()
comments = data[7].getText()

# %% [markdown]
# The above simply gets the text from each of the columns and saves to variables. Some of this data however needs further cleaning to remove unwanted characters or extract further information.

# %% [markdown]
# ## Data Cleaning
# If we print out the variable company, the text not only contains the **name of the company** but also a **description**. If we then print out sales, it contains unwanted characters such as footnote symbols that would be useful to remove.

# %%
print('Company is', company)
# Company is Wonderbly Personalised children's books          
print('Sales', sales)
# Sales *25,860
# Out:
# Company is Brompton TechnologyVideo technology provider
# Sales *5,250

# %% [markdown]
# We would like to split company into the company name and the description which we can do in a few lines of code. Looking again at the html, for this column there is a <span> element that contains only the company name. There is also a link in this column to another page on the website that has more detailed information about the company. We will be using this a little later!

# %% [raw]
# <td><a href="http://www.fasttrack.co.uk/company_profile/wonderbly-3/"><span class="company-name">Wonderbly</span></a>Personalised children's books</td>

# %% [markdown]
# To separate company into two fields, we can use the **find** method to save the <span> element and then use either **strip** or **replace** to remove the company name from the company variable, so that it leaves only the description.

# %%
# extract description from the name
companyname = data[1].find('span', attrs={'class':'company-name'}).getText()    
description = company.replace(companyname, '')
    
# remove unwanted characters
sales = sales.strip('*').strip('†').replace(',','')

# %%
print(companyname)
print(description)
print(sales)
# Out:
# Brompton Technology
# Video technology provider
# 5250

# %% [markdown]
# The last variable we would like to save is the company website. As discussed above, the second column contains a link to another page that has an overview of each company. Each company page has it’s own table, which most of the time contains the company website.

# %% [markdown]
# ### Inspecting the element of the url on the company page
# ![title](./../../img/fastTrack.png)

# %% [markdown]
# To scrape the url from each table and save it as a variable, we need to use the same steps as above:
#
# - Find the element that has the url of the the company page on the fast track website
# - Make a request to each company page url
# - Parse the html using Beautifulsoup
# - Find the elements of interest

# %% [markdown]
# Looking at a few of the company pages, as in the screenshot above, the urls are in last row in the table so we can search within the last row for the <a> element.

# %%
# go to link and extract company website
url = data[1].find('a').get('href')
page = urllib.request.urlopen(url)

# parse the html 
soup = BeautifulSoup(page, 'html.parser')

# find the last result in the table and get the link
try:
    tableRow = soup.find('table').find_all('tr')[-1]
    webpage = tableRow.find('a').get('href')
except:
    webpage = None

# %% [markdown]
# There also may be cases where the company website is not displayed so we can use a try except condition, in case a url is not foun

# %% [markdown]
# Once we have saved all of the data to variables, still within the loop, we can add each result to the list rows.

# %%
# write each result to rows
rows.append([rank, companyname, webpage, description, location, yearend, salesrise, sales, staff, comments])
print(rows)
# Out:
# [['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'], ['100', 'Brompton Technology', 'http://www.bromptontech.com', 'Video technology provider', 'West London', 'Aug-17', '50.17%', '5250', '27', 'Its technology is used in high-profile events such as the Oscars']]

# %% [markdown]
# It is then useful to print the variable outside of the loop, to check that it looks as you expect before writing it to a file!

# %% [markdown]
# NOTE: THE SCRIPT ABOVE NEEDS TO BE MODIFIED TO GENERATE THE 100 ROWS

# %% [markdown]
# ## Writing an output file
# You may want to save this data for analysis and this can be done very simply within python from our list.

# %%
# Create csv and write rows to output file
try:
    with open('./../../files/techtrack100.csv','w', newline='', encoding="utf-8") as f_output:
        csv_output = csv.writer(f_output)
        csv_output.writerows(rows)
        print('file successfully created')
except Exception as e:
    print ('The following error occured: ',str(e))
# Out:
# file successfully created

# %% [markdown]
# ### File Ouput - techtrack100.csv
#
# ![title](./../../img/TeckTrack100-csv.png)

# %% [markdown]
# ## Full Program

# %%
# -*- coding: utf-8 -*-

# importing libraries
from bs4 import BeautifulSoup
import urllib.request
import csv

#   Specify the URL
urlpage =   'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/'

#   Query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)

#   Parse the HTML using BS and store in variable 'Soup'
soup = BeautifulSoup(page,'html.parser')

#   Print the results
#print(soup)

#   Create customer error handler
#--------------

#   Find results within the table
table = soup.find('table', attrs={'class': 'tableSorter'})
results = table.find_all('tr')
print('Number of results', len(results))

#   Create and write headers to a list 
rows = []
rows.append(['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year End', 'Annual Sales Rise over 3 Years', ' Sales $000s', 'Staff', 'Comments',])
#print(rows)

#   Loop over the results
results = table.find_all('tr')
for result in results:
    #   Find all cloumns per result
    data = result.find_all('td')
    #   Check that columns have data
    if len(data) == 0:
        continue
    
    #   Write columsn to variables
    rank = data[0].getText()
    company = data[1].getText()
    location = data[2].getText()
    yearend = data[3].getText()
    salesrise = data[4].getText()
    sales = data[5].getText()
    staff = data[6].getText()
    comments = data[7].getText()
    #    print(rank)
    #    extract description from the name
    companyname = data[1].find('span', attrs={'class':'company-name'}).getText()    
    description = company.replace(companyname, '')
    
    #   remove unwanted characters
    sales = sales.strip('*').strip('†').replace(',','')

    #    go to link and extract company website
    url = data[1].find('a').get('href')
    page = urllib.request.urlopen(url)
    #    parse the html 
    soup = BeautifulSoup(page, 'html.parser')
    #    find the last result in the table and get the link
    try:
        tableRow = soup.find('table').find_all('tr')[-1]
        webpage = tableRow.find('a').get('href')
    except:
        webpage = None

    #    write each result to rows
    rows.append([rank, companyname, webpage, description, location, yearend, salesrise, sales, staff, comments])
    #print(rows)

#    Create csv and write rows to output file - amr - adding encoding
with open('techtrack100.csv','w', newline='', encoding="utf-8") as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerows(rows)
# Out:
# Number of results 101

# %% [markdown]
# ## Web Scraping Advice
# - Web scraping works best with **static, well-structured web pages**. Dynamic or interactive content on a web page is often not accessible through the HTML source, which makes scraping it much harder!
# - Web scraping is a "fragile" approach for building a dataset. The HTML on a page you are scraping can **change at any time**, which may cause your scraper to stop working.
# - If you can **download the data** you need from a website, or if the website provides an **API with data access**, those approaches are preferable to scraping since they are easier to implement and less likely to break.
# - If you are **scraping a lot of pages** from the same website (in rapid succession), it's best to insert delays in your code so that **you don't overwhelm** the website with requests. If the website decides you are causing a problem, they can block your IP address (which may affect everyone in your building!)
# - Before scraping a website, you should review its **robots.txt file** (also known as the [Robots exclusion standard](https://en.wikipedia.org/wiki/Robots_exclusion_standard)) to check whether you are "allowed" to scrape their website. (Here is the [robots.txt file for nytimes.com](http://www.nytimes.com/robots.txt).)

# %% [markdown]
# ## Summary
# This brief tutorial on web scraping with python has outlined:
#
# - Connecting to a webpage
# - Parsing html using BeautifulSoup
# - Looping through the soup object to find elements
# - Performing some simple data cleaning
# - Writing data to a csv

# %% [markdown]
# # Additional References
#
# - The [Beautiful Soup documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/) is written like a tutorial, and is worth reading to gain a detailed understanding of the library.
# - For more Beautiful Soup examples, see [Web Scraping 101 with Python](http://www.gregreda.com/2013/03/03/web-scraping-101-with-python/), [More web scraping with Python](http://www.gregreda.com/2013/04/29/more-web-scraping-with-python/), and this [web scraping lesson](http://web.stanford.edu/~zlotnick/TextAsData/Web_Scraping_with_Beautiful_Soup.html) from Stanford's "Text As Data" course.
# - [Web Scraping with Python](https://www.youtube.com/watch?v=p1iX0uxM1w8) is a 3-hour video tutorial covering Beautiful Soup and other scraping tools. (The [slides](https://docs.google.com/presentation/d/1uHM_esB13VuSf7O1ScGueisnrtu-6usGFD3fs4z5YCE/edit#slide=id.p) and [code](https://github.com/kjam/python-web-scraping-tutorial) are also available.)
# - [Scrapy](http://scrapy.org/) is a popular application framework that is useful for more complex web scraping projects.
# - [How a Math Genius Hacked OkCupid to Find True Love](http://www.wired.com/2014/01/how-to-hack-okcupid/all/) and [How Netflix Reverse Engineered Hollywood](http://www.theatlantic.com/technology/archive/2014/01/how-netflix-reverse-engineered-hollywood/282679/?single_page=true) are two fun examples of using web scraping to build an interesting dataset.
